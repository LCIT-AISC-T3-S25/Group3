# %% [markdown]
# # Project Checklist Report Table

# %% [markdown]
# | Model | Task | Status | Member Responsible |
# |-------|------|--------|---------------------|
# | **1. Causal Transformer** | Preprocessing Steps | Done/Pending | Advait Manishkumar Pandit |
# |  | Model Building & Training | Done/Pending | Advait Manishkumar Pandit |
# |  | Evaluation (ROUGE-L, BERT) | Done/Pending | Advait Manishkumar Pandit |
# |  | LIME Interpretation | Done/Pending | Advait Manishkumar Pandit |
# |  | Round 1 of Tuning | Done/Pending | Riya Kalpeshkumar Shah |
# |  | Round 2 of Tuning | Done/Pending | Riya Kalpeshkumar Shah |
# |  | Final AUC + Next Steps | Done/Pending | Riya Kalpeshkumar Shah |
# | **2. RAG (FAISS + LangChain)** | Preprocessing Steps | Done/Pending | Mueez Ur Rehman Amjad |
# |  | Model Building & Training | Done/Pending | Mueez Ur Rehman Amjad |
# |  | Evaluation | Done/Pending | Mueez Ur Rehman Amjad |
# |  | LIME + MAP/MRR | Done/Pending | Tanzima Mohammadyasin Shaikh  |
# |  | Round 1 of Tuning | Done/Pending | Tanzima Mohammadyasin Shaikh |
# |  | Round 2 of Tuning | Done/Pending | Tanzima Mohammadyasin Shaikh  |
# |  | Final AUC + Next Steps | Done/Pending | Tanzima Mohammadyasin Shaikh  |
# | **3. Transfer Learning (GPT-2 + PEFT)** | Preprocessing Steps | Done/Pending | Ashish Lama |
# |  | Model Building & Training | Done/Pending | Ashish Lama |
# |  | Evaluation | Done/Pending | Ashish Lama |
# |  | LIME / BERT-F1 | Done/Pending | Ashish Lama |
# |  | Round 1 of Tuning | Done/Pending | Om Kiranbhai Patel |
# |  | Round 2 of Tuning | Done/Pending | Om Kiranbhai Patel |
# |  | Final AUC + Next Steps | Done/Pending | Om Kiranbhai Patel |
# | **4. RAG + Query Rewriting (Gemma)** | Preprocessing + Query Rewriting | Done/Pending | Nischal Pradhan |
# |  | Model Building | Done/Pending | Nischal Pradhan |
# |  | Evaluation | Done/Pending | Nischal Pradhan |
# |  | LIME / MAP-MRR | Done/Pending | Nischal Pradhan |
# |  | Round 1 of Tuning | Done/Pending | Riya Kalpeshkumar Shah |
# |  | Round 2 of Tuning | Done/Pending | Riya Kalpeshkumar Shah |
# |  | Final AUC + Next Steps | Done/Pending | Riya Kalpeshkumar Shah |
# | **5. Prompt Engineering** | Prompt Framework Design (Few-Shot, CoT, DSP) | Done/Pending | Kanika |
# |  | Model Building / Prompt Testing Runs | Done/Pending | Kanika |
# |  | Evaluation (ROUGE-L, BERT-F1) | Done/Pending | Kanika |
# |  | Interpretation & Write-up | Done/Pending | Kanika |
# |  | Round 1 of Tuning (prompt edits + results tracking) | Done/Pending | Arish Panjwani |
# |  | Round 2 of Tuning + Prompt Stability Check | Done/Pending | Arish Panjwani |
# |  | Final AUC + Summary | Done/Pending | Arish Panjwani |
